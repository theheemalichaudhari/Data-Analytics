# %% [markdown]
# <a href="https://www.kaggle.com/code/heemalichaudhari/guide-to-become-leaf-doctor-with-deep-learning?scriptVersionId=116413386" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>
